# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamAnderB/Bramlett_DSPN_S24/blob/main/book/exercises/visualization-as-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5: Using ggplot

# %% [markdown]
# This homework assignment is designed to get you comfortable working with `ggplot` for generating data visualizations.
#
# We will be using the [gapminder](https://cran.r-project.org/web/packages/gapminder/index.html) dataset. It contains  information about population, life expectancy and per capita GDP by country over time.

# %% [markdown]
# ---
# # 1. Color, plot type and layers (6 points)

# %% [markdown]
# Install and load the `gapminder` dataset. Look at the first few rows of the data frame.

# %%
# INSERT CODE HERE
#install.packages("gapminder")
library(gapminder)
library(tidyverse)
data<-gapminder
# Out:
#      country     continent year lifeExp pop      gdpPercap
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803
# 13   Albania     Europe    1952 55.230   1282697 1601.0561
# 14   Albania     Europe    1957 59.280   1476505 1942.2842
# 15   Albania     Europe    1962 64.820   1728137 2312.8890
# 16   Albania     Europe    1967 66.220   1984060 2760.1969
# 17   Albania     Europe    1972 67.690   2263554 3313.4222
# 18   Albania     Europe    1977 68.930   2509048 3533.0039
# 19   Albania     Europe    1982 70.420   2780097 3630.8807
# 20   Albania     Europe    1987 72.000   3075321 3738.9327
# 21   Albania     Europe    1992 71.581   3326498 2497.4379
# 22   Albania     Europe    1997 72.950   3428038 3193.0546
# 23   Albania     Europe    2002 75.651   3508512 4604.2117
# 24   Albania     Europe    2007 76.423   3600523 5937.0295
# 25   Algeria     Africa    1952 43.077   9279525 2449.0082
# 26   Algeria     Africa    1957 45.685  10270856 3013.9760
# 27   Algeria     Africa    1962 48.303  11000948 2550.8169
# 28   Algeria     Africa    1967 51.407  12760499 3246.9918
# 29   Algeria     Africa    1972 54.518  14760787 4182.6638
# 30   Algeria     Africa    1977 58.014  17152804 4910.4168
# ⋮    ⋮           ⋮         ⋮    ⋮       ⋮        ⋮
# 1675 Yemen, Rep. Asia      1982 49.113   9657618 1977.5570
# 1676 Yemen, Rep. Asia      1987 52.922  11219340 1971.7415
# 1677 Yemen, Rep. Asia      1992 55.599  13367997 1879.4967
# 1678 Yemen, Rep. Asia      1997 58.020  15826497 2117.4845
# 1679 Yemen, Rep. Asia      2002 60.308  18701257 2234.8208
# 1680 Yemen, Rep. Asia      2007 62.698  22211743 2280.7699
# 1681 Zambia      Africa    1952 42.038   2672000 1147.3888
# 1682 Zambia      Africa    1957 44.077   3016000 1311.9568
# 1683 Zambia      Africa    1962 46.023   3421000 1452.7258
# 1684 Zambia      Africa    1967 47.768   3900000 1777.0773
# 1685 Zambia      Africa    1972 50.107   4506497 1773.4983
# 1686 Zambia      Africa    1977 51.386   5216550 1588.6883
# 1687 Zambia      Africa    1982 51.821   6100407 1408.6786
# 1688 Zambia      Africa    1987 50.821   7272406 1213.3151
# 1689 Zambia      Africa    1992 46.100   8381163 1210.8846
# 1690 Zambia      Africa    1997 40.238   9417789 1071.3538
# 1691 Zambia      Africa    2002 39.193  10595811 1071.6139
# 1692 Zambia      Africa    2007 42.384  11746035 1271.2116
# 1693 Zimbabwe    Africa    1952 48.451   3080907  406.8841
# 1694 Zimbabwe    Africa    1957 50.469   3646340  518.7643
# 1695 Zimbabwe    Africa    1962 52.358   4277736  527.2722
# 1696 Zimbabwe    Africa    1967 53.995   4995432  569.7951
# 1697 Zimbabwe    Africa    1972 55.635   5861135  799.3622
# 1698 Zimbabwe    Africa    1977 57.674   6642107  685.5877
# 1699 Zimbabwe    Africa    1982 60.363   7636524  788.8550
# 1700 Zimbabwe    Africa    1987 62.351   9216418  706.1573
# 1701 Zimbabwe    Africa    1992 60.377  10704340  693.4208
# 1702 Zimbabwe    Africa    1997 46.809  11404948  792.4500
# 1703 Zimbabwe    Africa    2002 39.989  11926563  672.0386
# 1704 Zimbabwe    Africa    2007 43.487  12311143  469.7093

# %% [markdown]
# Now, let's create a basic scatterplot using `ggplot2` that shows how life expectancy has changed over time.

# %%
# INSERT CODE HERE
data%>%ggplot(aes(x=year,y=lifeExp))+
  geom_point(alpha=.4)
# Out:
# plot without title

# %% [markdown]
# We can add another layer of detail by using color to indicate continent. Modify the code from the previous question to to do so.
#
# What trends can you identify in the data?

# %%
# INSERT CODE HERE
data%>%ggplot(aes(x=year,y=lifeExp,color=continent))+
  geom_point(alpha=.4)+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %% [markdown]
# > *Write your response here.*
# > * #overall, every continent is seeing greater life expectancy.
# It seems that Asia and Oceania countries have higher life expectancy and Africa and asia have some of the lowest. Europe probably has the highest on average life expectancy. But the Americas is getting better. While there is very little data on Oceania the life expectancy is pretty decent.*

# %% [markdown]
# Using a scatterplot probably isn’t the best type of plot for effectively visualizing change over time. Instead, modify the code from the previous question to create a line plot.

# %%
# INSERT CODE HERE
data%>%ggplot(aes(x=year,y=lifeExp,color=continent))+
  geom_line(alpha=.4)+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %% [markdown]
# Hmm, this plot looks a bit weird and unexpected, making it difficult for us to easily interpret the data trends. What is causing this?

# %% [markdown]
# > *Write your response here.*
# > * The problem is that there is more than one country at each year so the grouping is off. We need to group the data so that each line represents a single country rather than trying to draw between each country for each year. like below.

# %% [markdown]
# Now, let’s try to separate the data by country, plotting one line for each country. Modify the code from the previous plot to do so.

# %%
# INSERT CODE HERE
data%>%ggplot(aes(x=year,y=lifeExp,color=continent,group=country))+
  geom_line(alpha=.4)+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %% [markdown]
# But what if we want to visualize both lines and points on our graph? There are two primary ways to do this - taking advantage of what we know about using layers for ggplot (each layer is drawn on top of the previous layer).
#
# * Method 1: Plot black points on top of the colorful lines
# * Method 2: Plot black points underneath the colorful lines
#
# Modify the code from the previous question to create two plots, one for each method.
#
# *Hint: to control the color of the points, think about where the aesthetic color attribute should be located e.g., in the global plot options or in a specific layer.*

# %%
# INSERT CODE HERE

# method 1
data%>%ggplot(aes(x=year,y=lifeExp,color=continent,group=country))+
  geom_line()+
  geom_point(color="black")+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
# INSERT CODE HERE
# method 2
data%>%ggplot(aes(x=year,y=lifeExp,color=continent,group=country))+
  geom_point(color="black")+
  geom_line()+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
# Aside: colorful points
data%>%ggplot(aes(x=year,y=lifeExp,color=continent,group=country))+
  geom_point()+
  geom_line()+
  facet_grid(.~continent)+
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %% [markdown]
# ---
# # 2. Adding statistics (4 points)

# %% [markdown]
# `ggplot2` allows easy overlay of statistical models on top of the data.
#
# The graph below shows the relationship between life expectency and GDP per capita:

# %%
ggplot(data = gapminder, mapping = aes(x = gdpPercap, y = lifeExp)) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# However, the data points are squished close together on the left side of the graph, so it's hard to see the actual relationship we're interested in.
#
# To fix this, we can change the scale of x-axis units using the scale functions. We can also make the data points transparent using the alpha function. This is helpful when there is a large amount of clustered data.
#
# Modify the code above to incorporate these two changes (scale and transparency).

# %%
# INSERT CODE HERE
data%>%ggplot(mapping = aes(x = log(gdpPercap), y = log(lifeExp))) +
  geom_point(alpha=.5)
# Out:
# plot without title

# %% [markdown]
# Already we can more easily visualize the trend in the data.
#
# Next, let's overlay statistics by fiting a simple relationship to the data. Modify the code from the previous question by adding a `geom_smooth` layer.

# %%
# INSERT CODE HERE
data%>%ggplot(mapping = aes(x = log(gdpPercap), y = log(lifeExp))) +
  geom_point(alpha=.5)+
  geom_smooth(method="lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# Again, we can add a layer of detail by introducing separate colors for each continent. We can also create individual trendlines for each continent, instead of only one trendline.
#
# Modify the code from the previous question to add these elements.

# %%
# INSERT CODE HERE
data%>%
  ggplot(mapping = aes(x = log(gdpPercap), y = log(lifeExp),color=continent)) +
  geom_point(alpha=.5)+
  geom_smooth(method="lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# When you are finished, save the notebook as Exercise5.ipynb, push it to your class GitHub repository and send the instructors a link to your notebook via Canvas.

# %% [markdown]
# **DUE:** 5pm EST, Feb 14, 2024

# %% [markdown]
# **IMPORTANT** Did you collaborate with anyone on this assignment? If so, list their names here.
# > *just me this time*
